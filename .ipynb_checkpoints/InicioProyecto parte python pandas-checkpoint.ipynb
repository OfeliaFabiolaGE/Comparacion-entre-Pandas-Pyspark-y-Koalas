# %%
#haremos varias consultas para mostrar los datos el primero sera analizar 
#los datos, el segundo sera filtrar y manipular los datos, despues 
#seleccionaremos columnas y filas especificas, tambien selecciones condicionales
#y al final usaremos graficos en pandas.
import pandas as pd
import time
import datetime
import numpy as np

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
pip install pyspark
# Out:
# ...
#   Using cached pyspark-3.3.1-py2.py3-none-any.whl
# ...
#   Using cached py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df1 = pd.read_csv("C:/Users/ofeliafabiola.galvan/Documents/FGITHU/datasetproyecto-las-tres-partes/Course_info.csv")
df1
# Out:
#                id                                              title  is_paid  \
# 0          4715.0             Online Vegan Vegetarian Cooking School     True
# 1          1769.0         The Lean Startup Talk at Stanford E-Corner    False
# 2          5664.0  How To Become a Vegan, Vegetarian, or Flexitarian     True
# 3          7723.0                               How to Train a Puppy     True
# 4          8157.0                      Web Design from the Ground Up     True
# ...           ...                                                ...      ...
# 209729  4913954.0                Let's Speak Urdu - The Urdu Grammar     True
# 209730  4914146.0  CompTIA Linux+ (XKO-004/005 # 2 Practice Exam ...     True
# 209731  4914002.0  CISSP 4 full exams #1 : All CISSP domains - 12...     True
# 209732  4913934.0  JD Edwards EnterpriseOne Fixed Assets Accounti...     True
# 209733  4914054.0  CISSP 4 full exams #2 : All CISSP domains - 12...     True
#
# ...

# %%
df1[df1['language'] != 'English']
# Out:
#                id                                              title  is_paid  \
# 9          8069.0                                   Curso SEO Online     True
# 63        11051.0                          Introducción a JavaScript     True
# 69        12123.0  Oracle Veritabanı Programlama : SQL, PL/SQL, O...     True
# 76        12124.0                       Oracle SQL Developer Eğitimi    False
# 84        13216.0  Aprende a tocar Piano o Teclado (Desde nivel b...     True
# ...           ...                                                ...      ...
# 209703  4911594.0           Como criar e usar mapas mentais digitais     True
# 209705  4912058.0  2023 HSBC Online Immersive Assessment OIA Summ...     True
# 209708  4912208.0                                     流行钢琴/电子琴即兴伴奏入门     True
# 209710  4911934.0                                圓周長與扇形弧長-國小六年級上學期數學     True
# 209714  4911842.0           Full Stack Flutter PHP: Build Pemilu App     True
#
# ...

# %%
#Veamos el total de filas y columnas de nuestro dataset
df1.shape
# Out:
# (209734, 20)

# %%
#Veamos el tipo de datos que contiene el dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209734 entries, 0 to 209733
# Data columns (total 20 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   id                  209734 non-null  float64
#  1   title               209734 non-null  object
#  2   is_paid             209734 non-null  bool
#  3   price               209734 non-null  float64
#  4   headline            209707 non-null  object
#  5   num_subscribers     209734 non-null  float64
#  6   avg_rating          209734 non-null  float64
#  7   num_reviews         209734 non-null  float64
#  8   num_comments        209734 non-null  float64
#  9   num_lectures        209734 non-null  float64
#  10  content_length_min  209734 non-null  float64
#  11  published_time      209734 non-null  object
#  12  last_update_date    209597 non-null  object
#  13  category            209734 non-null  object
#  14  subcategory         209734 non-null  object
# ...

# %%
#Como notamos hay muchos valores NaN por lo que los vamos a sustituir por 0 
df1=df1.fillna(0)
print(df1)
# Out:
#                id                                              title  is_paid  \
# 0          4715.0             Online Vegan Vegetarian Cooking School     True
# 1          1769.0         The Lean Startup Talk at Stanford E-Corner    False
# 2          5664.0  How To Become a Vegan, Vegetarian, or Flexitarian     True
# 3          7723.0                               How to Train a Puppy     True
# 4          8157.0                      Web Design from the Ground Up     True
# ...           ...                                                ...      ...
# 209729  4913954.0                Let's Speak Urdu - The Urdu Grammar     True
# 209730  4914146.0  CompTIA Linux+ (XKO-004/005 # 2 Practice Exam ...     True
# 209731  4914002.0  CISSP 4 full exams #1 : All CISSP domains - 12...     True
# 209732  4913934.0  JD Edwards EnterpriseOne Fixed Assets Accounti...     True
# 209733  4914054.0  CISSP 4 full exams #2 : All CISSP domains - 12...     True
#
# ...

# %%
df1.head(5)
# Out:
#        id                                              title  is_paid   price  \
# 0  4715.0             Online Vegan Vegetarian Cooking School     True   24.99
# 1  1769.0         The Lean Startup Talk at Stanford E-Corner    False    0.00
# 2  5664.0  How To Become a Vegan, Vegetarian, or Flexitarian     True   19.99
# 3  7723.0                               How to Train a Puppy     True  199.99
# 4  8157.0                      Web Design from the Ground Up     True  159.99
#
#                                             headline  num_subscribers  \
# 0  Learn to cook delicious vegan recipes. Filmed ...           2231.0
# 1  Debunking Myths of Entrepreneurship A startup ...          26474.0
# 2  Get the tools you need for a lifestyle change ...           1713.0
# 3  Train your puppy the right way with Dr. Ian Du...           4988.0
# 4  Learn web design online: Everything you need t...           1266.0
#
# ...

# %%
df1.tail(10)
# Out:
#                id                                              title  is_paid  \
# 209724  4912840.0                               Top 5 Academic Hacks     True
# 209725  4913148.0  Osteo eCourses - Working With The Electromagne...     True
# 209726  4912976.0  COBIT 5 Foundation - Practice Exam - Updated O...     True
# 209727  4913922.0                            The Latin Passive Voice     True
# 209728  4914102.0  CompTIA Linux+ (XKO-004/005 # 1 Practice Exam ...     True
# 209729  4913954.0                Let's Speak Urdu - The Urdu Grammar     True
# 209730  4914146.0  CompTIA Linux+ (XKO-004/005 # 2 Practice Exam ...     True
# 209731  4914002.0  CISSP 4 full exams #1 : All CISSP domains - 12...     True
# 209732  4913934.0  JD Edwards EnterpriseOne Fixed Assets Accounti...     True
# 209733  4914054.0  CISSP 4 full exams #2 : All CISSP domains - 12...     True
#
#          price                                           headline  \
# ...

# %%
df1.describe()
# Out:
#                  id          price  num_subscribers     avg_rating  \
# count  2.097340e+05  209734.000000     2.097340e+05  209734.000000
# mean   3.015403e+06      81.665529     3.096992e+03       3.747179
# std    1.342558e+06     117.317846     1.558132e+04       1.533711
# min    1.769000e+03       0.000000     0.000000e+00       0.000000
# 25%    1.950734e+06      19.990000     2.600000e+01       3.800000
# 50%    3.292863e+06      34.990000     2.060000e+02       4.333334
# 75%    4.189458e+06      99.990000     1.435000e+03       4.625000
# max    4.914146e+06     999.990000     1.752364e+06       5.000000
#
#          num_reviews   num_comments   num_lectures  content_length_min
# count  209734.000000  209734.000000  209734.000000       209734.000000
# mean      244.358812      44.874589      36.548395          265.558856
# std      2458.098276     355.773107      51.871962          454.448676
# min         0.000000       0.000000       0.000000            0.000000
# ...

# %%
#Parte 2 Filtrar y manipular los datos de df1
#para ello seleccionaremos columnas y filas especificas y le aplicaremos un describe
Id = df1['id']
Id
# Out:
# 0            4715.0
# 1            1769.0
# 2            5664.0
# 3            7723.0
# 4            8157.0
#             ...
# 209729    4913954.0
# 209730    4914146.0
# 209731    4914002.0
# 209732    4913934.0
# 209733    4914054.0
# Name: id, Length: 209734, dtype: float64

# %%
Title = df1['title']
Title
# Out:
# 0                    Online Vegan Vegetarian Cooking School
# 1                The Lean Startup Talk at Stanford E-Corner
# 2         How To Become a Vegan, Vegetarian, or Flexitarian
# 3                                      How to Train a Puppy
# 4                             Web Design from the Ground Up
#                                 ...
# 209729                  Let's Speak Urdu - The Urdu Grammar
# 209730    CompTIA Linux+ (XKO-004/005 # 2 Practice Exam ...
# 209731    CISSP 4 full exams #1 : All CISSP domains - 12...
# 209732    JD Edwards EnterpriseOne Fixed Assets Accounti...
# 209733    CISSP 4 full exams #2 : All CISSP domains - 12...
# Name: title, Length: 209734, dtype: object

# %%
Id2 = df1['id'==33250]
Id2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\Anaconda3\envs\Proyecto2\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\Anaconda3\envs\Proyecto2\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\Anaconda3\envs\Proyecto2\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
Price = df1['price']
Price
# Out:
# 0          24.99
# 1           0.00
# 2          19.99
# 3         199.99
# 4         159.99
#            ...
# 209729     19.99
# 209730     49.99
# 209731     49.99
# 209732    119.99
# 209733     49.99
# Name: price, Length: 209734, dtype: float64

# %%
Is_paid = df1['is_paid']
Is_paid
# Out:
# 0          True
# 1         False
# 2          True
# 3          True
# 4          True
#           ...
# 209729     True
# 209730     True
# 209731     True
# 209732     True
# 209733     True
# Name: is_paid, Length: 209734, dtype: bool

# %%
Price = df1['price']
Price
# Out:
# 0          24.99
# 1           0.00
# 2          19.99
# 3         199.99
# 4         159.99
#            ...
# 209729     19.99
# 209730     49.99
# 209731     49.99
# 209732    119.99
# 209733     49.99
# Name: price, Length: 209734, dtype: float64

# %%
Headline = df1['headline']
Headline
# Out:
# 0         Learn to cook delicious vegan recipes. Filmed ...
# 1         Debunking Myths of Entrepreneurship A startup ...
# 2         Get the tools you need for a lifestyle change ...
# 3         Train your puppy the right way with Dr. Ian Du...
# 4         Learn web design online: Everything you need t...
#                                 ...
# 209729    Urdu - Become fluent in this beautiful South A...
# 209730    Practice Latest exam questions with detailed e...
# 209731    Practice Latest exam questions with detailed e...
# 209732    Full-length course (Part-3 of 3) on JD Edwards...
# 209733    Practice Latest exam questions with detailed e...
# Name: headline, Length: 209734, dtype: object

# %%
Num_subscribers = df1['num_subscribers']
Num_subscribers
# Out:
# 0          2231.0
# 1         26474.0
# 2          1713.0
# 3          4988.0
# 4          1266.0
#            ...
# 209729        3.0
# 209730        0.0
# 209731        0.0
# 209732        0.0
# 209733        0.0
# Name: num_subscribers, Length: 209734, dtype: float64

# %%
Avg_rating = df1['avg_rating']
Avg_rating
# Out:
# 0         3.75
# 1         4.50
# 2         4.40
# 3         4.80
# 4         4.75
#           ...
# 209729    0.00
# 209730    0.00
# 209731    0.00
# 209732    0.00
# 209733    0.00
# Name: avg_rating, Length: 209734, dtype: float64

# %%
Num_reviews = df1['num_reviews']
Num_reviews
# Out:
# 0         134.0
# 1         709.0
# 2          41.0
# 3         395.0
# 4          38.0
#           ...
# 209729      0.0
# 209730      0.0
# 209731      0.0
# 209732      0.0
# 209733      0.0
# Name: num_reviews, Length: 209734, dtype: float64

# %%
Num_comments = df1['num_comments']
Num_comments
# Out:
# 0          42.0
# 1         112.0
# 2          13.0
# 3          88.0
# 4          12.0
#           ...
# 209729      0.0
# 209730      0.0
# 209731      0.0
# 209732      0.0
# 209733      0.0
# Name: num_comments, Length: 209734, dtype: float64

# %%
Num_lectures = df1['num_lectures']
Num_lectures
# Out:
# 0         37.0
# 1          9.0
# 2         14.0
# 3         36.0
# 4         38.0
#           ...
# 209729     5.0
# 209730     0.0
# 209731     0.0
# 209732     9.0
# 209733     0.0
# Name: num_lectures, Length: 209734, dtype: float64

# %%
Content_length_min = df1['content_length_min']
Content_length_min
# Out:
# 0         1268.0
# 1           88.0
# 2           82.0
# 3         1511.0
# 4          569.0
#            ...
# 209729      54.0
# 209730       0.0
# 209731       0.0
# 209732      82.0
# 209733       0.0
# Name: content_length_min, Length: 209734, dtype: float64

# %%
Published_time = df1['published_time']
Published_time
# Out:
# 0         2010-08-05T22:06:13Z
# 1         2010-01-12T18:09:46Z
# 2         2010-10-13T18:07:17Z
# 3         2011-06-20T20:08:38Z
# 4         2011-06-23T18:31:20Z
#                   ...
# 209729    2022-10-05T11:31:36Z
# 209730    2022-10-05T12:29:23Z
# 209731    2022-10-05T11:04:05Z
# 209732    2022-10-05T10:30:19Z
# 209733    2022-10-05T11:36:34Z
# Name: published_time, Length: 209734, dtype: object

# %%
Last_update_date = df1['last_update_date']
Last_update_date
# Out:
# 0         2020-11-06
# 1                  0
# 2         2019-10-09
# 3         2016-01-13
# 4                  0
#              ...
# 209729    2022-10-06
# 209730    2022-10-05
# 209731    2022-10-05
# 209732    2022-10-05
# 209733    2022-10-05
# Name: last_update_date, Length: 209734, dtype: object

# %%
Category = df1['category']
Category
# Out:
# 0                    Lifestyle
# 1                     Business
# 2                    Lifestyle
# 3                    Lifestyle
# 4                       Design
#                   ...
# 209729    Teaching & Academics
# 209730           IT & Software
# 209731           IT & Software
# 209732    Finance & Accounting
# 209733           IT & Software
# Name: category, Length: 209734, dtype: object

# %%
Subcategory = df1['subcategory']
Subcategory
# Out:
# 0                    Food & Beverage
# 1                   Entrepreneurship
# 2                    Other Lifestyle
# 3                Pet Care & Training
# 4                         Web Design
#                      ...
# 209729             Language Learning
# 209730             IT Certifications
# 209731             IT Certifications
# 209732    Other Finance & Accounting
# 209733             IT Certifications
# Name: subcategory, Length: 209734, dtype: object

# %%
Topic = df1['topic']
Topic
# Out:
# 0                                             Vegan Cooking
# 1                                              Lean Startup
# 2                                             Vegan Cooking
# 3                                              Pet Training
# 4                                                Web Design
#                                 ...
# 209729                                        Urdu Language
# 209730                                       CompTIA Linux+
# 209731    CISSP - Certified Information Systems Security...
# 209732                                 Financial Accounting
# 209733    CISSP - Certified Information Systems Security...
# Name: topic, Length: 209734, dtype: object

# %%
Language = df1['language']
Language
# Out:
# 0         English
# 1         English
# 2         English
# 3         English
# 4         English
#            ...
# 209729    English
# 209730    English
# 209731    English
# 209732    English
# 209733    English
# Name: language, Length: 209734, dtype: object

# %%
Course_url = df1['course_url']
Course_url
# Out:
# 0                  /course/vegan-vegetarian-cooking-school/
# 1         /course/the-lean-startup-debunking-myths-of-en...
# 2         /course/see-my-personal-motivation-for-becomin...
# 3                       /course/complete-dunbar-collection/
# 4                    /course/web-design-from-the-ground-up/
#                                 ...
# 209729                 /course/lets-speak-urdu-the-grammar/
# 209730    /course/comptia-linux-xko-004005-2-practice-ex...
# 209731    /course/cissp-4-full-exams-1-all-cissp-domains...
# 209732          /course/jde-fixed-assets-accounting-part-3/
# 209733    /course/cissp-4-full-exams-2-all-cissp-domains...
# Name: course_url, Length: 209734, dtype: object

# %%
Instructor_name = df1['instructor_name']
Instructor_name
# Out:
# 0                     Angela Poch
# 1                       Eric Ries
# 2                     Angela Poch
# 3                      Ian Dunbar
# 4                  E Learning Lab
#                    ...
# 209729              Jawaid Hameed
# 209730    Jean-François d'Halluin
# 209731    Jean-François d'Halluin
# 209732            Niranjan Bhatia
# 209733    Jean-François d'Halluin
# Name: instructor_name, Length: 209734, dtype: object

# %%
Instructor_url = df1['instructor_url']
Instructor_url
# Out:
# 0                          /user/angelapoch/
# 1                            /user/ericries/
# 2                          /user/angelapoch/
# 3                          /user/ian-dunbar/
# 4                         /user/edwin-ang-2/
#                          ...
# 209729                  /user/jawaid-hameed/
# 209730                     /user/badre-lini/
# 209731                     /user/badre-lini/
# 209732    /user/systemic-software-solutions/
# 209733                     /user/badre-lini/
# Name: instructor_url, Length: 209734, dtype: object

# %%
df1.iloc[0]
# Out:
# id                                                               4715.0
# title                            Online Vegan Vegetarian Cooking School
# is_paid                                                            True
# price                                                             24.99
# headline              Learn to cook delicious vegan recipes. Filmed ...
# num_subscribers                                                  2231.0
# avg_rating                                                         3.75
# num_reviews                                                       134.0
# num_comments                                                       42.0
# num_lectures                                                       37.0
# content_length_min                                               1268.0
# published_time                                     2010-08-05T22:06:13Z
# last_update_date                                             2020-11-06
# ...

# %%
df1.iloc[100]
# Out:
# id                                                              14434.0
# title                           Creating an MP3 Player with Adobe Flash
# is_paid                                                           False
# price                                                               0.0
# headline              Learn how to make an custom Mp3 player with Ad...
# num_subscribers                                                  9196.0
# avg_rating                                                          4.0
# num_reviews                                                        92.0
# num_comments                                                       20.0
# num_lectures                                                        7.0
# content_length_min                                                 70.0
# published_time                                     2012-03-22T22:18:49Z
# last_update_date                                             2020-10-03
# ...

# %%
df1.loc[0:1]
# Out:
#        id                                       title  is_paid  price  \
# 0  4715.0      Online Vegan Vegetarian Cooking School     True  24.99
# 1  1769.0  The Lean Startup Talk at Stanford E-Corner    False   0.00
#
#                                             headline  num_subscribers  \
# 0  Learn to cook delicious vegan recipes. Filmed ...           2231.0
# 1  Debunking Myths of Entrepreneurship A startup ...          26474.0
#
#    avg_rating  num_reviews  num_comments  num_lectures  content_length_min  \
# 0        3.75        134.0          42.0          37.0              1268.0
# 1        4.50        709.0         112.0           9.0                88.0
#
#          published_time last_update_date   category       subcategory  \
# 0  2010-08-05T22:06:13Z       2020-11-06  Lifestyle   Food & Beverage
# 1  2010-01-12T18:09:46Z                0   Business  Entrepreneurship
#
#            topic language                                         course_url  \
# ...

# %%
df1.loc[0:0]
# Out:
#        id                                   title  is_paid  price  \
# 0  4715.0  Online Vegan Vegetarian Cooking School     True  24.99
#
#                                             headline  num_subscribers  \
# 0  Learn to cook delicious vegan recipes. Filmed ...           2231.0
#
#    avg_rating  num_reviews  num_comments  num_lectures  content_length_min  \
# 0        3.75        134.0          42.0          37.0              1268.0
#
#          published_time last_update_date   category      subcategory  \
# 0  2010-08-05T22:06:13Z       2020-11-06  Lifestyle  Food & Beverage
#
#            topic language                                course_url  \
# 0  Vegan Cooking  English  /course/vegan-vegetarian-cooking-school/
#
#   instructor_name     instructor_url
# 0     Angela Poch  /user/angelapoch/

# %%
df1[df1['num_subscribers']>1000000]
# Out:
#              id                                              title  is_paid  \
# 396     24823.0               Java Tutorial for Complete Beginners    False
# 10174  543600.0  Automate the Boring Stuff with Python Programming     True
# 10724  567828.0  2022 Complete Python Bootcamp From Zero to Her...     True
# 16288  793796.0  Microsoft Excel - Excel from Beginner to Advanced     True
#
#         price                                           headline  \
# 396      0.00  Learn to program using the Java programming la...
# 10174   49.99  A practical programming course for office work...
# 10724  199.99  Learn Python like a Professional  Start from t...
# 16288  149.99  Excel with this A-Z Microsoft Excel Course. Mi...
#
#        num_subscribers  avg_rating  num_reviews  num_comments  num_lectures  \
# 396          1752364.0    4.444383      96582.0       14919.0          74.0
# 10174        1056369.0    4.676586     102876.0       13544.0          51.0
# ...

# %%
Ejemplo=df1[(df1['price'] == 0) & (df1['category'] == 'Development') & (df1['topic'] == 'Python') & 
             (df1['language'] == 'English') & (df1['num_lectures'] > 50) | (df1['num_subscribers'] > 600000)]
rng=np.random.RandomState(0)
x=Ejemplo['id'].values
y=Ejemplo['topic'].values
colors=rng.rand(23)
plt.scatter(x,y,c=colors,alpha=0.4,cmap='viridis')
plt.gca().update(dict(title='grafica',xlabel='suscritos',ylabel='vistasmedi',ylim=(0,10)))
plt.colorbar();

# %%
#Busquemos el mejor "curso" filtrado por el numero de subscriptores, que use python y su lenguaje impartido sea ingles, además de 
#un numero de lecturas mayor a 50, y un plus que su precio sea gratis
df1[(df1['price'] == 0) & (df1['category'] == 'Development') & (df1['topic'] == 'Python') & 
             (df1['language'] == 'English') & (df1['num_lectures'] > 50) & (df1['num_subscribers'] > 600000)]
# Out:
#             id                               title  is_paid  price  \
# 7802  433798.0  Introduction To Python Programming    False    0.0
#
#                                             headline  num_subscribers  \
# 7802  A Quick and Easy Intro into Python Programming           783638
#
#       avg_rating  num_reviews  num_comments  num_lectures  content_length_min  \
# 7802    4.437906      62061.0        8482.0          56.0               100.0
#
#             published_time last_update_date     category  \
# 7802  2015-03-02T01:23:00Z       2020-07-29  Development
#
#                 subcategory   topic language  \
# 7802  Programming Languages  Python  English
#
#                             course_url instructor_name       instructor_url
# 7802  /course/pythonforbeginnersintro/    Avinash Jain  /user/avinashjain5/

# %%
df1[(df1['price'] == 0) & (df1['topic'] == 'Python') & (df1['num_lectures'] > 50) & (df1['num_subscribers'] > 600000)]
# Out:
#             id                               title  is_paid  price  \
# 7802  433798.0  Introduction To Python Programming    False    0.0
#
#                                             headline  num_subscribers  \
# 7802  A Quick and Easy Intro into Python Programming           783638
#
#       avg_rating  num_reviews  num_comments  num_lectures  content_length_min  \
# 7802    4.437906      62061.0        8482.0          56.0               100.0
#
#             published_time last_update_date     category  \
# 7802  2015-03-02T01:23:00Z       2020-07-29  Development
#
#                 subcategory   topic language  \
# 7802  Programming Languages  Python  English
#
#                             course_url instructor_name       instructor_url
# 7802  /course/pythonforbeginnersintro/    Avinash Jain  /user/avinashjain5/

# %%
df1['num_subscribers'] = df1['num_subscribers'].astype(int)

# %%
#hagamos una grafica en forma de pastel en la que se muestre el rating respecto al numero de subscriptores
import matplotlib.pyplot as plt
rng = np.random.RandomState(0)
x = df1['num_subscribers'].values
y = df1['avg_rating'].values
colors = rng.rand(209734)
plt.scatter(x, y, c=colors, alpha=0.4, cmap='viridis')
plt.gca().update(dict(title='grafica',xlabel='suscritos',ylabel='vistasmedi',ylim=(0,10)))
plt.colorbar();
